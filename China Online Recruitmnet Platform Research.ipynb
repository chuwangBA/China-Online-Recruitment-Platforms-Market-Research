# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.charts import Page, Pie
from pyecharts.charts import Line
from pyecharts.globals import ThemeType

x=["2017/12","2018/03","2018/06","2018/09","2018/12"]
y=[3827,5843,7356,7655,8232]

bar=Bar(init_opts=opts.InitOpts(theme=ThemeType.CHALK))
bar.add_xaxis(x)
bar.add_yaxis("User Volume",y,category_gap=["100"],markpoint_opts=opts.MarkPointOpts(
                data=[opts.MarkPointItem(coord=[x[2], y[2]], value=y[2]),opts.MarkPointItem(coord=[x[0], y[0]], value=y[0]),
                      opts.MarkPointItem(coord=[x[1], y[1]], value=y[1]),opts.MarkPointItem(coord=[x[3], y[3]], value=y[3]),
                      opts.MarkPointItem(coord=[x[4], y[4]], value=y[4])]))

bar.extend_axis(
    yaxis=opts.AxisOpts(
        axislabel_opts=opts.LabelOpts(formatter="{value} %"), interval=2
    ))
bar.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
bar.set_global_opts(
    title_opts=opts.TitleOpts(title="APP Penetration Rate &User Volume"),
    yaxis_opts=opts.AxisOpts(
        axislabel_opts=opts.LabelOpts(formatter="{value} w"))
            )

line = Line()
line.add_xaxis(["2017/12","2018/03","2018/06","2018/09","2018/12"])
line.add_yaxis("Penetration", [3.75,5.41,6.69,6.96,7.48], yaxis_index=1,symbol="triangle")
bar.overlap(line).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'chalk':'https://assets.pyecharts.org/assets/themes/chalk'
#         }
#     });
# </script>
#
#     <div id="dba827b840f8413384560d22cb79959b" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'chalk'], function(echarts) {
#         var chart_dba827b840f8413384560d22cb79959b = echarts.init(
#             document.getElementById('dba827b840f8413384560d22cb79959b'), 'chalk', {renderer: 'canvas'});
#         var option_dba827b840f8413384560d22cb79959b = {
#     "series": [
#         {
#             "type": "bar",
#             "name": "User Volume",
#             "data": [
#                 3827,
#                 5843,
#                 7356,
#                 7655,
#                 8232
#             ],
#             "barCategoryGap": [
#                 "100"
#             ],
#             "label": {
# ...

# %%
pie=Pie(init_opts=opts.InitOpts(theme=ThemeType.CHALK))
pie.add(
            "",
            [list(z) for z in zip(['Tier1','New Tier1','Tier2','Tier3','Tier4','Below Tier5'],[18.8,26.5,20.1,16.1,11.4,7.1])],
            radius=["30%", "75%"],
           
            rosetype="radius",
            label_opts=opts.LabelOpts(is_show=False),
        )
pie.set_global_opts(toolbox_opts=opts.ToolboxOpts(),
           title_opts=opts.TitleOpts("APP User Location-by level of cities"),legend_opts=opts.LegendOpts(orient="vertical",pos_top="10%",pos_left="9%"))
pie.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}%"))
pie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'chalk':'https://assets.pyecharts.org/assets/themes/chalk'
#         }
#     });
# </script>
#
#     <div id="52f235c3149e438687e9f1bbc610cd0b" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'chalk'], function(echarts) {
#         var chart_52f235c3149e438687e9f1bbc610cd0b = echarts.init(
#             document.getElementById('52f235c3149e438687e9f1bbc610cd0b'), 'chalk', {renderer: 'canvas'});
#         var option_52f235c3149e438687e9f1bbc610cd0b = {
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "Tier1",
#                     "value": 18.8
#                 },
#                 {
#                     "name": "New Tier1",
#                     "value": 26.5
#                 },
#                 {
# ...

# %%
from pyecharts.charts import Page, Radar

radar=Radar(init_opts=opts.InitOpts(theme=ThemeType.CHALK))

radar.add_schema(
            schema=[
                opts.RadarIndicatorItem(name="Weighted Wechat Reading Volume", max_=21.5),
                opts.RadarIndicatorItem(name="Weighted Weibo Fans", max_=26.6),
                opts.RadarIndicatorItem(name="Weighted App Comments", max_=39.5),
                opts.RadarIndicatorItem(name="Weighted Baidu News Trend", max_=18),
                opts.RadarIndicatorItem(name="Weighted Penetration Rate", max_=24.4),
                opts.RadarIndicatorItem(name="Weighted Daily Active User", max_=33.1)
            ]
        )
radar.add("领英",[[21.5,1.5,3.4,6.6,11.6,4.9]],areastyle_opts=opts.AreaStyleOpts(opacity=0.5),color='#58CAD1')
radar.add("智联招聘",[[14,13.9,8.2,9.7,17.4,10.2]],areastyle_opts=opts.AreaStyleOpts(opacity=0.5),color='#EF864B')
radar.add("脉脉",[[11.5,0.9,9.9,4.6,24.4,33.1]],areastyle_opts=opts.AreaStyleOpts(opacity=0.5),color='#1E4DF0')
radar.add("招才猫",[[8.1,0,0.9,0.8,4.7,5.8]],areastyle_opts=opts.AreaStyleOpts(opacity=0.5),color='#F9020A')
radar.add("猎聘",[[7.7,5.1,4.5,6.3,5.8,5]],areastyle_opts=opts.AreaStyleOpts(opacity=0.5),color='#00F41F')
radar.add("看准网",[[7.4,7.7,0.3,5.8,1.2,0.5]],areastyle_opts=opts.AreaStyleOpts(opacity=0.5),color='#34C71B')
radar.add("前程无忧",[[7.2,18.1,13.4,14.1,16.3,20.1]],areastyle_opts=opts.AreaStyleOpts(opacity=0.5),color='#FFFD2D')
radar.add("Boss直聘",[[3.6,4.6,39.5,8.5,12.8,14.9]],areastyle_opts=opts.AreaStyleOpts(opacity=0.5),color='#7CF9F9')
radar.add("拉勾网",[[3.2,0.8,1.7,3.5,2.3,3.9]],areastyle_opts=opts.AreaStyleOpts(opacity=0.5),color='#0EEB88')
radar.add("斗米",[[0.8,1.6,0.6,7.7,3.5,1.7]],areastyle_opts=opts.AreaStyleOpts(opacity=0.5),color='#ED97F0')

radar.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
radar.set_global_opts(
    title_opts=opts.TitleOpts(title=""),
)
radar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'chalk':'https://assets.pyecharts.org/assets/themes/chalk'
#         }
#     });
# </script>
#
#     <div id="7d06a9c0cca14dfb9a620e589bc4f259" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'chalk'], function(echarts) {
#         var chart_7d06a9c0cca14dfb9a620e589bc4f259 = echarts.init(
#             document.getElementById('7d06a9c0cca14dfb9a620e589bc4f259'), 'chalk', {renderer: 'canvas'});
#         var option_7d06a9c0cca14dfb9a620e589bc4f259 = {
#     "series": [
#         {
#             "type": "radar",
#             "name": "\u9886\u82f1",
#             "data": [
#                 [
#                     21.5,
#                     1.5,
#                     3.4,
#                     6.6,
#                     11.6,
#                     4.9
#                 ]
#             ],
#             "label": {
# ...

# %%
bar=Bar(init_opts=opts.InitOpts(theme=ThemeType.DARK))
bar.add_xaxis(["前程无忧","脉脉","Boss直聘","智联招聘","领英","猎聘","看准网","招才猫","斗米","拉勾网"])
bar.add_yaxis("",[89.2,84.4,83.9,73.4,49.5,34.4,22.9,20.3,15.9,15.4],category_gap=["40"]
             )
bar.set_global_opts(toolbox_opts=opts.ToolboxOpts(),
            title_opts=opts.TitleOpts(title="TOP10 Online Recruitment Platform Overall Weighted Scores"),
    yaxis_opts=opts.AxisOpts(
        axislabel_opts=opts.LabelOpts(formatter="{value} ")
    )
)
bar.set_series_opts(
            label_opts=opts.LabelOpts(is_show=False),
            
            markpoint_opts=opts.MarkPointOpts(
                data=[
                    opts.MarkPointItem(type_="max", name="Max"),
                    opts.MarkPointItem(type_="min", name="Min")
                ]
            ),
            markline_opts=opts.MarkLineOpts(
                data=[
                    opts.MarkLineItem(type_="average", name="Average")
                ]
            )
            )
    
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="308c81434d0846588f72ccf11460bac9" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_308c81434d0846588f72ccf11460bac9 = echarts.init(
#             document.getElementById('308c81434d0846588f72ccf11460bac9'), 'dark', {renderer: 'canvas'});
#         var option_308c81434d0846588f72ccf11460bac9 = {
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 89.2,
#                 84.4,
#                 83.9,
#                 73.4,
#                 49.5,
#                 34.4,
#                 22.9,
#                 20.3,
#                 15.9,
#                 15.4
#             ],
#             "barCategoryGap": [
#                 "40"
#             ],
#             "label": {
# ...
